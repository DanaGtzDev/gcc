# %%
# %pip install pandas
# %pip install matplotlib
# Out:
# 405.35s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.
# 410.91s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.2 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 4.1 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 4.1 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
climate_21 = pd.read_csv("./clima/info_clima_chihuahua_2021.csv")
climate_21.keys()
"""
'fecha', 'temp_out (Grados C)', 'hi_temp (Grados C)',
'low_temp (Grados C)', 'out_hum (%)', 'dew_Pt (Grados C)',
'wind_Speed (km/h)', 'wind_dir (Grados )', 'wind_run (km)',
'hi_speed (km/h)', 'hi_Dir (Grados )', 'wind_chill (Grados C)',
'heat_Index (Grados C)', 'tHW_index (Grados C)',
'tHSW_index (Grados C)', 'bar (mb)', 'rain (mm)', 'rain_rate (mm/hr)',
'solar_rad (W/m2)', 'solar_energy (MJ/m2)', 'hi_solar_rad (W/m2)',
'uv_index (UV)', 'uv_dose (MEDs)', 'hi_uv (UV)',
'Heat_dd (Grados C dias grado-calor)', 'cool_dd (Grados C)',
'in_temp (Grados C)', 'in_hum (%)', 'in_dew (Grados C)',
'in_heat (Grados C)', 'in_emc (g/m3)', 'in_air (kg/cu.m)', 'ET (mm)',
'wind_samp', 'wind_tx', 'iss_recept (%)', 'arc_int (minutos)',
'created_at', 'updated_at', 'Unnamed: 39'
"""
# Out:
# "\n'fecha', 'temp_out (Grados C)', 'hi_temp (Grados C)',\n'low_temp (Grados C)', 'out_hum (%)', 'dew_Pt (Grados C)',\n'wind_Speed (km/h)', 'wind_dir (Grados )', 'wind_run (km)',\n'hi_speed (km/h)', 'hi_Dir (Grados )', 'wind_chill (Grados C)',\n'heat_Index (Grados C)', 'tHW_index (Grados C)',\n'tHSW_index (Grados C)', 'bar (mb)', 'rain (mm)', 'rain_rate (mm/hr)',\n'solar_rad (W/m2)', 'solar_energy (MJ/m2)', 'hi_solar_rad (W/m2)',\n'uv_index (UV)', 'uv_dose (MEDs)', 'hi_uv (UV)',\n'Heat_dd (Grados C dias grado-calor)', 'cool_dd (Grados C)',\n'in_temp (Grados C)', 'in_hum (%)', 'in_dew (Grados C)',\n'in_heat (Grados C)', 'in_emc (g/m3)', 'in_air (kg/cu.m)', 'ET (mm)',\n'wind_samp', 'wind_tx', 'iss_recept (%)', 'arc_int (minutos)',\n'created_at', 'updated_at', 'Unnamed: 39'\n"

# %%
climate_21["wind_Speed (km/h)"].plot()
# Out:
# <Axes: >
