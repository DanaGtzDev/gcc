# %%
import pandas as pd

# %%
df_one = pd.read_csv("pendiente/Sheet1.csv")
df_one
# Out:
#           FECHA     PLANTA UNIDAD     ESTATUS      MARCA  MODELO  \
# 0    2026-01-02   TOLEDANO  13042  DISPONIBLE  SINOTRUCK  2024.0
# 1    2026-01-02   TOLEDANO   9636  DISPONIBLE   KENWORTH  2018.0
# 2    2026-01-02    IMPULSO   9631  DISPONIBLE   KENWORTH  2018.0
# 3    2026-01-03    IMPULSO   9631  DISPONIBLE   KENWORTH  2018.0
# 4    2026-01-02  SUPERIOR    6600  DISPONIBLE   KENWORTH  2016.0
# ..          ...        ...    ...         ...        ...     ...
# 506  2026-02-04  SUPERIOR    6600  DISPONIBLE   KENWORTH  2016.0
# 507  2026-02-05   TOLEDANO   9432  DISPONIBLE   KENWORTH  2017.0
# 508  2026-02-06    IMPULSO  13218  DISPONIBLE  SINOTRUCK  2024.0
# 509  2026-02-06     HOMERO  12193  DISPONIBLE   KENWORTH  2022.0
# 510  2026-02-06    IMPULSO  13221  DISPONIBLE  SINOTRUCK  2024.0
#
#                     Discripción de Falla TIPO DE FALLA  EQUIPO     TALLER  \
# 0                 TUBO DE AGUA QUEBRADO       MECANICO  ALIADO  RAYMUNDO
# ...

# %%
df_two = pd.read_csv("pendiente/Sheet2.csv")
df_two.count()
# Out:
# unidad       267
# localidad    267
# planta       267
# dtype: int64
